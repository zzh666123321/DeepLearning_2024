# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
img = []
file = []
for i in range(1,6):
    f = '1-' + str(i) + '.png'
    file.append(f)
    temp = cv.imread(f,0)
    img.append(temp)

plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img[i],'gray')
    
plt.show()

# %%
print(np.array(img).shape)
print(type(img[0]))
h , w= img[0].shape
print(h,w)
# Out:
# (5, 350, 300)
# <class 'numpy.ndarray'>
# 350 300

# %%
plt.figure(figsize=(10,25))
for i in range(0,5): 
    plt.subplot(5,1,i+1)
    plt.title(file[i])
    plt.hist(img[i].ravel(),256)
plt.show()

# %%
plt.title(file[i])
plt.hist(img[i].ravel(),256)
plt.show()

# %%
color1 = [0,0,0]
color2 = [0,255,255]
color3 = [255,0,0]
color4 = [0,100,0]
color5 = [0,0,255]

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点
th1 = 5
th2 = 35
th3 = 90
th4 = 120
img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
import cv2 as cv
import numpy as np
np.seterr(invalid='ignore') #之所以加这一句是因为下面除法的时候会除零报错
import matplotlib.pyplot as plt
import time
start = time.perf_counter()


def ostu5layers(img,i):  # 显示每一个灰度级的像素数概率
    print('Processing:img-'+str(i))
    high, wide = (h,w)
    pixels = cv.calcHist([img], [0], None, [256], [0, 256])  # 计算每个灰度级中所含像素数，返回的是一个（256,1）的数组
    p = pixels / (high * wide)  # 获得每个灰度级中像素数占总像素数比例则我们获得了p_i的一个向量
    x=np.linspace(1,256,256) #灰度级我们定义为从0到255好像不合适这样做平均灰度级时会忽略第一个数据，所以我们定义为从1到256
    x=x.reshape(256,1)  # 这一步是因为我们需要的不是秩为1的向量，可以不加这一句输出看看shape的区别，但这样我们得到了（256,1）的灰度级向量

    maxvar=0
    th1=0
    th2=0
    th3=0
    th4=0
    cnt=0
    for k1 in range(1,10):
        for k2 in range(k1+1,50):
            for k3 in range(50,110):
                for k4 in range(110,140):
                    w0 = np.sum(p[0:k1])
                    w1 = np.sum(p[k1:k2])
                    w2 = np.sum(p[k2:k3])
                    w3 = np.sum(p[k3:k4])
                    w4 = np.sum(p[k4:256])  # 注意python是左闭右开np.sum(p[0:256])=1
                    
                    u0 = np.dot(x[0:k1].T, p[0:k1])
                    u1 = np.dot(x[k1:k2].T, p[k1:k2])
                    u2 = np.dot(x[k2:k3].T, p[k2:k3])
                    u3 = np.dot(x[k3:k4].T, p[k3:k4])
                    u4 = np.dot(x[k4:256].T, p[k4:256])
                    
                    W = np.array([[w0, w1, w2, w3, w4]]).T  # 注意是两层中括号，用np.array组成的向量可以转置,输出矩阵大小等等操作
                    U = np.array([[int(u0), int(u1), int(u2), int(u3), int(u4)]]).T
                    UT = np.sum(U)
                    temp = (U - UT * W) * (U - UT * W) / W
                    varbetween = np.sum(temp)
                    if varbetween>maxvar:
                        cnt=cnt+1
                        maxvar=varbetween
                        th1=k1
                        th2=k2
                        th3=k3
                        th4=k4
                        print("第"+str(cnt)+"次找到最佳阈值："+str(th1)+","+str(th2)+","+str(th3)+","+str(th4)+","+"此时类间方差为"+str(maxvar))
                        end = time.perf_counter()
                        print('Running time: %s Seconds' % (end - start))
    # mean1 = int(np.dot(x[0:th1].T, p[0:th1]))
    # mean2 = int(np.dot(x[th1:th2].T, p[th1:th2]))
    # mean3 = int(np.dot(x[th2:256].T, p[th2:256]))
    
    img11 = np.zeros((350, 300,3),dtype=np.uint8)
    for row in range(0,h):
        for col in range(0,w):
            if img[row][col]<=th1:
                img11[row, col]=color1
            elif img[row][col]>th1 and img[row][col]<=th2:
                img11[row, col] =color2
            elif img[row][col]>th2 and img[row][col]<=th3:
                img11[row, col] = color3
            elif img[row][col]>th3 and img[row][col]<=th4:
                img11[row, col] = color4
            elif img[row][col]>th4:
                img11[row, col] = color5
    return img11

if __name__ == '__main__':
    img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
    for i in range(0,5):
        start = time.perf_counter()
        img1[i]=ostu5layers(img[i],i)
    plt.figure(figsize=(25,20))
    for i in range(0,5): 
        plt.subplot(1,5,i+1)
        plt.axis('off')
        plt.title(file[i])
        plt.imshow(img1[i])
    plt.show()
# Out:
# Processing:img-0
# 第1次找到最佳阈值：1,10,50,110,此时类间方差为1814.6592036172108
# Running time: 0.8462008000000001 Seconds
# 第2次找到最佳阈值：1,10,50,115,此时类间方差为1822.8209144440623
# Running time: 0.8467734 Seconds
# 第3次找到最佳阈值：1,10,50,121,此时类间方差为1825.0640734773883
# Running time: 0.8474092999999989 Seconds
# 第4次找到最佳阈值：1,10,51,115,此时类间方差为1857.0140852959487
# Running time: 0.8502048000000002 Seconds
# 第5次找到最佳阈值：1,10,51,121,此时类间方差为1859.4457681756505
# Running time: 0.8511445000000002 Seconds
# 第6次找到最佳阈值：1,10,53,110,此时类间方差为1865.925808477047
# Running time: 0.8545113999999998 Seconds
# 第7次找到最佳阈值：1,10,53,115,此时类间方差为1874.1762466584223
# Running time: 0.8552347000000005 Seconds
# 第8次找到最佳阈值：1,10,53,121,此时类间方差为1876.48353343537
# Running time: 0.8559543999999999 Seconds
# 第9次找到最佳阈值：1,10,56,115,此时类间方差为1876.8137739446497
# Running time: 0.8614464000000002 Seconds
# 第10次找到最佳阈值：1,10,56,121,此时类间方差为1879.628485781007
# Running time: 0.8620737999999992 Seconds
# 第11次找到最佳阈值：1,10,58,121,此时类间方差为1881.058061420292
# Running time: 0.8663194999999995 Seconds
# 第12次找到最佳阈值：1,10,59,110,此时类间方差为1896.5476758819073
# Running time: 0.8682952000000004 Seconds
# 第13次找到最佳阈值：1,10,59,115,此时类间方差为1905.4406868172064
# Running time: 0.8690611999999991 Seconds
# 第14次找到最佳阈值：1,10,59,121,此时类间方差为1908.2134955571205
# Running time: 0.8698130000000006 Seconds
# 第15次找到最佳阈值：1,10,68,115,此时类间方差为1917.2835529871313
# Running time: 0.8854310999999999 Seconds
# 第16次找到最佳阈值：1,10,68,121,此时类间方差为1920.6221395537139
# Running time: 0.8860493999999992 Seconds
# 第17次找到最佳阈值：1,11,64,115,此时类间方差为1929.3399921121438
# Running time: 0.9819511999999992 Seconds
# 第18次找到最佳阈值：1,11,64,121,此时类间方差为1932.4768547492276
# Running time: 0.9825950999999993 Seconds
# 第19次找到最佳阈值：1,12,60,110,此时类间方差为1937.9615412252833
# Running time: 1.0837491000000004 Seconds
# 第20次找到最佳阈值：1,12,60,115,此时类间方差为1947.0814419868486
# Running time: 1.0842334999999999 Seconds
# 第21次找到最佳阈值：1,12,60,121,此时类间方差为1950.0239322926438
# Running time: 1.084632599999999 Seconds
# 第22次找到最佳阈值：1,13,55,115,此时类间方差为1950.181255148288
# Running time: 1.1804729999999992 Seconds
# 第23次找到最佳阈值：1,13,55,121,此时类间方差为1952.8354413287518
# Running time: 1.1815896000000006 Seconds
# 第24次找到最佳阈值：1,13,60,115,此时类间方差为1954.2233278629017
# Running time: 1.1908522999999995 Seconds
# 第25次找到最佳阈值：1,13,60,121,此时类间方差为1957.165818168697
# Running time: 1.1914736000000001 Seconds
# 第26次找到最佳阈值：1,13,69,110,此时类间方差为1966.9305943387883
# Running time: 1.207538399999999 Seconds
# 第27次找到最佳阈值：1,13,69,115,此时类间方差为1976.7694462781892
# Running time: 1.2078758 Seconds
# 第28次找到最佳阈值：1,13,69,121,此时类间方差为1980.28202355126
# Running time: 1.2088848999999993 Seconds
# 第29次找到最佳阈值：1,14,61,110,此时类间方差为1982.3834447524443
# Running time: 1.3012830999999991 Seconds
# 第30次找到最佳阈值：1,14,61,115,此时类间方差为1991.7034228575817
# Running time: 1.3019295 Seconds
# 第31次找到最佳阈值：1,14,61,121,此时类间方差为1994.7987950252793
# Running time: 1.3033748000000003 Seconds
# 第32次找到最佳阈值：1,15,61,115,此时类间方差为1997.6488392020626
# Running time: 1.4071309000000003 Seconds
# 第33次找到最佳阈值：1,15,61,121,此时类间方差为2000.7442113697603
# Running time: 1.4079683000000003 Seconds
# 第34次找到最佳阈值：1,15,69,121,此时类间方差为2000.8411792127802
# Running time: 1.422734499999999 Seconds
# 第35次找到最佳阈值：1,15,78,115,此时类间方差为2010.448725373116
# Running time: 1.4382704000000004 Seconds
# 第36次找到最佳阈值：1,15,78,121,此时类间方差为2014.3774382912388
# Running time: 1.4388962000000003 Seconds
# 第37次找到最佳阈值：1,15,78,135,此时类间方差为2014.8863463170198
# Running time: 1.4406064999999995 Seconds
# 第38次找到最佳阈值：1,16,78,115,此时类间方差为2023.890808485105
# Running time: 1.5460118999999999 Seconds
# 第39次找到最佳阈值：1,16,78,121,此时类间方差为2027.8195214032278
# Running time: 1.5466856 Seconds
# 第40次找到最佳阈值：1,16,78,135,此时类间方差为2028.3284294290088
# Running time: 1.5481940000000005 Seconds
# 第41次找到最佳阈值：1,17,78,115,此时类间方差为2033.4949051219005
# Running time: 1.6534733 Seconds
# 第42次找到最佳阈值：1,17,78,121,此时类间方差为2037.4236180400233
# Running time: 1.6541134 Seconds
# 第43次找到最佳阈值：1,17,78,135,此时类间方差为2037.9325260658043
# Running time: 1.6555338000000006 Seconds
# 第44次找到最佳阈值：1,18,78,115,此时类间方差为2041.572145920071
# Running time: 1.7629403999999997 Seconds
# 第45次找到最佳阈值：1,18,78,121,此时类间方差为2045.5008588381938
# Running time: 1.7635582999999997 Seconds
# 第46次找到最佳阈值：1,18,78,135,此时类间方差为2046.0097668639748
# Running time: 1.7655920999999992 Seconds
# 第47次找到最佳阈值：1,19,78,115,此时类间方差为2047.411192586584
# Running time: 1.8711704999999998 Seconds
# 第48次找到最佳阈值：1,19,78,121,此时类间方差为2051.3399055047066
# Running time: 1.8718267999999991 Seconds
# 第49次找到最佳阈值：1,19,78,135,此时类间方差为2051.848813530488
# Running time: 1.8734570000000001 Seconds
# 第50次找到最佳阈值：1,20,78,115,此时类间方差为2053.121467433308
# Running time: 1.979743299999999 Seconds
# 第51次找到最佳阈值：1,20,78,121,此时类间方差为2057.050180351431
# Running time: 1.9804277999999993 Seconds
# 第52次找到最佳阈值：1,20,78,135,此时类间方差为2057.5590883772124
# Running time: 1.9820156999999998 Seconds
# 第53次找到最佳阈值：1,21,78,115,此时类间方差为2058.5380726838202
# Running time: 2.0891462999999995 Seconds
# 第54次找到最佳阈值：1,21,78,121,此时类间方差为2062.466785601943
# Running time: 2.089770999999999 Seconds
# 第55次找到最佳阈值：1,21,78,135,此时类间方差为2062.975693627724
# Running time: 2.0916859 Seconds
# 第56次找到最佳阈值：1,22,78,115,此时类间方差为2063.331397426041
# Running time: 2.1917504 Seconds
# 第57次找到最佳阈值：1,22,78,121,此时类间方差为2067.2601103441634
# Running time: 2.1924443999999994 Seconds
# 第58次找到最佳阈值：1,22,78,135,此时类间方差为2067.7690183699447
# Running time: 2.1942641 Seconds
# 第59次找到最佳阈值：1,23,78,115,此时类间方差为2067.88349541507
# Running time: 2.3026178999999996 Seconds
# 第60次找到最佳阈值：1,23,78,121,此时类间方差为2071.8122083331928
# Running time: 2.3032406000000005 Seconds
# 第61次找到最佳阈值：1,23,78,135,此时类间方差为2072.321116358974
# Running time: 2.304878499999999 Seconds
# 第62次找到最佳阈值：1,24,78,115,此时类间方差为2072.5381041022033
# Running time: 2.409746799999999 Seconds
# 第63次找到最佳阈值：1,24,78,121,此时类间方差为2076.466817020326
# Running time: 2.410780899999999 Seconds
# 第64次找到最佳阈值：1,24,78,135,此时类间方差为2076.975725046107
# Running time: 2.412928599999999 Seconds
# 第65次找到最佳阈值：1,25,72,121,此时类间方差为2078.6047441337164
# Running time: 2.5063621000000005 Seconds
# 第66次找到最佳阈值：1,25,78,121,此时类间方差为2080.8287952896176
# Running time: 2.5177964 Seconds
# 第67次找到最佳阈值：1,25,78,135,此时类间方差为2081.337703315399
# Running time: 2.5195527 Seconds
# Processing:img-1
# 第1次找到最佳阈值：1,11,50,110,此时类间方差为1825.1750384354648
# Running time: 1.0021685999999974 Seconds
# 第2次找到最佳阈值：1,11,50,113,此时类间方差为1833.6014297608565
# Running time: 1.0025078999999977 Seconds
# 第3次找到最佳阈值：1,11,50,114,此时类间方差为1848.1786919072592
# Running time: 1.0026617999999985 Seconds
# 第4次找到最佳阈值：1,11,50,120,此时类间方差为1851.307862070826
# Running time: 1.0031751 Seconds
# 第5次找到最佳阈值：1,11,51,114,此时类间方差为1885.4947407521538
# Running time: 1.0053146999999996 Seconds
# 第6次找到最佳阈值：1,11,51,120,此时类间方差为1888.8122408262766
# Running time: 1.0063889999999986 Seconds
# 第7次找到最佳阈值：1,11,53,114,此时类间方差为1899.5555217829572
# Running time: 1.0098331000000016 Seconds
# 第8次找到最佳阈值：1,11,53,120,此时类间方差为1902.7455878459732
# Running time: 1.0105216999999982 Seconds
# 第9次找到最佳阈值：1,11,57,114,此时类间方差为1927.6564731236458
# Running time: 1.0176607000000004 Seconds
# 第10次找到最佳阈值：1,11,57,120,此时类间方差为1931.4302793074671
# Running time: 1.0180568999999977 Seconds
# 第11次找到最佳阈值：1,11,62,120,此时类间方差为1949.619580062222
# Running time: 1.0271517999999986 Seconds
# 第12次找到最佳阈值：1,12,62,120,此时类间方差为1954.8247226581248
# Running time: 1.1342073 Seconds
# 第13次找到最佳阈值：1,13,62,120,此时类间方差为1967.196002387559
# Running time: 1.2397800999999973 Seconds
# 第14次找到最佳阈值：1,13,64,114,此时类间方差为1970.3637917180752
# Running time: 1.2433909000000014 Seconds
# 第15次找到最佳阈值：1,13,64,120,此时类间方差为1974.3337172126046
# Running time: 1.243957100000003 Seconds
# 第16次找到最佳阈值：1,14,55,114,此时类间方差为1975.6015408089959
# Running time: 1.332980499999998 Seconds
# 第17次找到最佳阈值：1,14,55,120,此时类间方差为1979.0896862925038
# Running time: 1.3336326000000014 Seconds
# 第18次找到最佳阈值：1,14,60,114,此时类间方差为1984.7326735002096
# Running time: 1.3436321000000007 Seconds
# 第19次找到最佳阈值：1,14,60,120,此时类间方差为1988.503384748809
# Running time: 1.344185600000003 Seconds
# 第20次找到最佳阈值：1,14,69,113,此时类间方差为1995.943405480928
# Running time: 1.3602270000000019 Seconds
# 第21次找到最佳阈值：1,14,69,114,此时类间方差为2009.085505658932
# Running time: 1.3603299000000035 Seconds
# 第22次找到最佳阈值：1,14,69,120,此时类间方差为2013.3703877464961
# Running time: 1.3608790999999982 Seconds
# 第23次找到最佳阈值：1,15,61,114,此时类间方差为2023.3716687396945
# Running time: 1.4602051000000031 Seconds
# 第24次找到最佳阈值：1,15,61,120,此时类间方差为2027.2896850460274
# Running time: 1.460690200000002 Seconds
# 第25次找到最佳阈值：1,16,61,114,此时类间方差为2030.125176171549
# Running time: 1.5715931000000012 Seconds
# 第26次找到最佳阈值：1,16,61,120,此时类间方差为2034.0431924778818
# Running time: 1.5720049999999972 Seconds
# 第27次找到最佳阈值：1,16,65,120,此时类间方差为2034.836730845935
# Running time: 1.580440699999997 Seconds
# 第28次找到最佳阈值：1,16,74,114,此时类间方差为2051.5231794028164
# Running time: 1.5972282000000035 Seconds
# 第29次找到最佳阈值：1,16,74,120,此时类间方差为2056.063405448249
# Running time: 1.597625800000003 Seconds
# 第30次找到最佳阈值：1,16,74,134,此时类间方差为2056.4095198839645
# Running time: 1.5990889999999993 Seconds
# 第31次找到最佳阈值：1,17,66,114,此时类间方差为2066.6323434044475
# Running time: 1.6914257999999975 Seconds
# 第32次找到最佳阈值：1,17,66,120,此时类间方差为2070.884330117298
# Running time: 1.6918269000000024 Seconds
# 第33次找到最佳阈值：1,18,66,114,此时类间方差为2071.926079540883
# Running time: 1.8045236999999972 Seconds
# 第34次找到最佳阈值：1,18,66,120,此时类间方差为2076.1780662537335
# Running time: 1.8049761999999987 Seconds
# 第35次找到最佳阈值：1,18,70,120,此时类间方差为2077.013167710316
# Running time: 1.8131586000000013 Seconds
# 第36次找到最佳阈值：1,18,79,134,此时类间方差为2077.1932015189946
# Running time: 1.830567000000002 Seconds
# 第37次找到最佳阈值：1,19,62,120,此时类间方差为2081.1404738176593
# Running time: 1.9068572999999986 Seconds
# 第38次找到最佳阈值：1,19,70,120,此时类间方差为2081.338214720078
# Running time: 1.9225546999999992 Seconds
# 第39次找到最佳阈值：1,19,79,120,此时类间方差为2081.6971134872592
# Running time: 1.9388040999999987 Seconds
# 第40次找到最佳阈值：1,19,79,134,此时类间方差为2082.6079385038925
# Running time: 1.9396664000000001 Seconds
# 第41次找到最佳阈值：1,20,62,120,此时类间方差为2084.273773331252
# Running time: 2.0163676000000024 Seconds
# 第42次找到最佳阈值：1,20,70,120,此时类间方差为2085.7947735401513
# Running time: 2.0311504000000014 Seconds
# 第43次找到最佳阈值：1,20,79,120,此时类间方差为2087.245873503905
# Running time: 2.0483614999999986 Seconds
# 第44次找到最佳阈值：1,20,79,134,此时类间方差为2088.156698520538
# Running time: 2.0497935 Seconds
# 第45次找到最佳阈值：1,21,70,120,此时类间方差为2089.954266352411
# Running time: 2.144789600000003 Seconds
# 第46次找到最佳阈值：1,21,79,120,此时类间方差为2092.3969467223515
# Running time: 2.162596399999998 Seconds
# 第47次找到最佳阈值：1,21,79,134,此时类间方差为2093.3077717389847
# Running time: 2.1635095000000035 Seconds
# 第48次找到最佳阈值：1,22,70,120,此时类间方差为2093.567615405733
# Running time: 2.255407499999997 Seconds
# 第49次找到最佳阈值：1,22,79,120,此时类间方差为2096.850047449331
# Running time: 2.272486200000003 Seconds
# 第50次找到最佳阈值：1,22,79,134,此时类间方差为2097.7608724659644
# Running time: 2.2735145999999986 Seconds
# 第51次找到最佳阈值：1,23,79,120,此时类间方差为2101.5751956601744
# Running time: 2.387526000000001 Seconds
# 第52次找到最佳阈值：1,23,79,134,此时类间方差为2102.4860206768076
# Running time: 2.388684699999999 Seconds
# 第53次找到最佳阈值：1,24,79,120,此时类间方差为2105.789747169463
# Running time: 2.4960109000000017 Seconds
# 第54次找到最佳阈值：1,24,79,134,此时类间方差为2106.7005721860965
# Running time: 2.497573899999999 Seconds
# 第55次找到最佳阈值：4,24,79,134,此时类间方差为2106.700572186097
# Running time: 17.268056100000003 Seconds
# Processing:img-2
# 第1次找到最佳阈值：1,10,50,110,此时类间方差为1810.4992794880704
# Running time: 0.8355808999999965 Seconds
# 第2次找到最佳阈值：1,10,50,114,此时类间方差为1871.4534848254732
# Running time: 0.8361048000000011 Seconds
# 第3次找到最佳阈值：1,10,50,120,此时类间方差为1874.9047046872577
# Running time: 0.8371546999999993 Seconds
# 第4次找到最佳阈值：1,10,52,110,此时类间方差为1875.7421135972004
# Running time: 0.8408948000000009 Seconds
# 第5次找到最佳阈值：1,10,52,114,此时类间方差为1885.958121494915
# Running time: 0.8414930999999939 Seconds
# 第6次找到最佳阈值：1,10,52,120,此时类间方差为1889.2827897793109
# Running time: 0.8423024999999882 Seconds
# 第7次找到最佳阈值：1,10,56,120,此时类间方差为1916.9636679247433
# Running time: 0.8495269999999948 Seconds
# 第8次找到最佳阈值：1,10,58,120,此时类间方差为1919.1933428164916
# Running time: 0.8534168999999991 Seconds
# 第9次找到最佳阈值：1,10,61,120,此时类间方差为1929.7174416529149
# Running time: 0.8587934999999902 Seconds
# 第10次找到最佳阈值：1,10,61,134,此时类间方差为1930.3108902102904
# Running time: 0.8604706999999934 Seconds
# 第11次找到最佳阈值：1,10,63,114,此时类间方差为1934.3916146325246
# Running time: 0.8631508999999937 Seconds
# 第12次找到最佳阈值：1,10,63,120,此时类间方差为1938.4668817065667
# Running time: 0.8638472999999891 Seconds
# 第13次找到最佳阈值：1,10,63,134,此时类间方差为1938.7216725477933
# Running time: 0.8653647999999947 Seconds
# 第14次找到最佳阈值：1,11,63,120,此时类间方差为1941.7061488336176
# Running time: 0.9663127999999972 Seconds
# 第15次找到最佳阈值：1,11,63,134,此时类间方差为1941.9609396748442
# Running time: 0.9681615999999877 Seconds
# 第16次找到最佳阈值：1,12,59,110,此时类间方差为1943.7632898769734
# Running time: 1.0637605999999948 Seconds
# 第17次找到最佳阈值：1,12,59,114,此时类间方差为1954.1232074627344
# Running time: 1.0641866999999934 Seconds
# 第18次找到最佳阈值：1,12,59,120,此时类间方差为1958.019687354154
# Running time: 1.0650572999999923 Seconds
# 第19次找到最佳阈值：1,12,72,120,此时类间方差为1958.632552725871
# Running time: 1.088303400000001 Seconds
# 第20次找到最佳阈值：1,12,72,134,此时类间方差为1960.3159017462017
# Running time: 1.0897583999999938 Seconds
# 第21次找到最佳阈值：1,13,54,120,此时类间方差为1963.6881528199347
# Running time: 1.1608567999999906 Seconds
# 第22次找到最佳阈值：1,13,59,120,此时类间方差为1967.2874772970658
# Running time: 1.1701043999999996 Seconds
# 第23次找到最佳阈值：1,13,64,110,此时类间方差为1976.2926879437664
# Running time: 1.1792498999999879 Seconds
# 第24次找到最佳阈值：1,13,64,114,此时类间方差为1986.701397180994
# Running time: 1.1797308999999956 Seconds
# 第25次找到最佳阈值：1,13,64,120,此时类间方差为1990.9240440038902
# Running time: 1.1803424999999947 Seconds
# 第26次找到最佳阈值：1,13,64,134,此时类间方差为1991.6352347827337
# Running time: 1.1820902999999987 Seconds
# 第27次找到最佳阈值：1,14,55,114,此时类间方差为1995.6780907211592
# Running time: 1.273203599999988 Seconds
# 第28次找到最佳阈值：1,14,55,120,此时类间方差为1999.4530745491156
# Running time: 1.2738184999999902 Seconds
# 第29次找到最佳阈值：1,14,60,114,此时类间方差为2003.4339032365392
# Running time: 1.2832334000000003 Seconds
# 第30次找到最佳阈值：1,14,60,120,此时类间方差为2007.4779919924026
# Running time: 1.2838805999999892 Seconds
# 第31次找到最佳阈值：1,14,60,134,此时类间方差为2007.631814475351
# Running time: 1.285419300000001 Seconds
# 第32次找到最佳阈值：1,14,73,114,此时类间方差为2014.1866976358017
# Running time: 1.3074791999999889 Seconds
# 第33次找到最佳阈值：1,14,73,120,此时类间方差为2018.8386934943705
# Running time: 1.3080968000000013 Seconds
# 第34次找到最佳阈值：1,14,73,134,此时类间方差为2020.9424597673792
# Running time: 1.3095927999999901 Seconds
# 第35次找到最佳阈值：1,15,65,114,此时类间方差为2035.8200681507647
# Running time: 1.399821799999998 Seconds
# 第36次找到最佳阈值：1,15,65,120,此时类间方差为2040.1731768755012
# Running time: 1.4004820999999907 Seconds
# 第37次找到最佳阈值：1,15,65,134,此时类间方差为2041.2954984160665
# Running time: 1.4020790999999946 Seconds
# 第38次找到最佳阈值：1,16,61,120,此时类间方差为2052.760609239731
# Running time: 1.500396699999996 Seconds
# 第39次找到最佳阈值：1,16,61,134,此时类间方差为2053.354057797106
# Running time: 1.5018936999999966 Seconds
# 第40次找到最佳阈值：1,16,74,120,此时类间方差为2066.136757443801
# Running time: 1.5239454999999964 Seconds
# 第41次找到最佳阈值：1,16,74,134,此时类间方差为2068.583771562372
# Running time: 1.5253780999999975 Seconds
# 第42次找到最佳阈值：1,17,74,120,此时类间方差为2073.8679244088407
# Running time: 1.629528999999991 Seconds
# 第43次找到最佳阈值：1,17,74,134,此时类间方差为2076.314938527412
# Running time: 1.6307375999999891 Seconds
# 第44次找到最佳阈值：1,18,74,120,此时类间方差为2080.3715392111385
# Running time: 1.7378214000000014 Seconds
# 第45次找到最佳阈值：1,18,74,134,此时类间方差为2082.8185533297096
# Running time: 1.7395089999999982 Seconds
# 第46次找到最佳阈值：1,19,74,120,此时类间方差为2085.3068683023653
# Running time: 1.843477699999994 Seconds
# 第47次找到最佳阈值：1,19,74,134,此时类间方差为2087.7538824209364
# Running time: 1.844970399999994 Seconds
# 第48次找到最佳阈值：1,20,74,120,此时类间方差为2090.502084429403
# Running time: 1.9503411999999969 Seconds
# 第49次找到最佳阈值：1,20,74,134,此时类间方差为2092.9490985479742
# Running time: 1.9516191999999961 Seconds
# 第50次找到最佳阈值：1,21,74,120,此时类间方差为2095.018354688019
# Running time: 2.056390499999992 Seconds
# 第51次找到最佳阈值：1,21,74,134,此时类间方差为2097.46536880659
# Running time: 2.057866599999997 Seconds
# 第52次找到最佳阈值：1,22,74,120,此时类间方差为2099.008929680223
# Running time: 2.1615760999999907 Seconds
# 第53次找到最佳阈值：1,22,74,134,此时类间方差为2101.455943798794
# Running time: 2.1634084999999885 Seconds
# 第54次找到最佳阈值：1,23,74,120,此时类间方差为2103.14162639044
# Running time: 2.267837 Seconds
# 第55次找到最佳阈值：1,23,74,134,此时类间方差为2105.588640509011
# Running time: 2.269587699999988 Seconds
# 第56次找到最佳阈值：1,24,74,120,此时类间方差为2107.4234346840867
# Running time: 2.374046899999996 Seconds
# 第57次找到最佳阈值：1,24,74,134,此时类间方差为2109.870448802658
# Running time: 2.375439499999999 Seconds
# Processing:img-3
# 第1次找到最佳阈值：1,10,50,110,此时类间方差为1809.6727938431009
# Running time: 0.8484342999999797 Seconds
# 第2次找到最佳阈值：1,10,50,113,此时类间方差为1813.196787647559
# Running time: 0.8487775999999769 Seconds
# 第3次找到最佳阈值：1,10,50,114,此时类间方差为1877.7658869032891
# Running time: 0.8489395000000002 Seconds
# 第4次找到最佳阈值：1,10,50,120,此时类间方差为1881.1652894506742
# Running time: 0.84958069999999 Seconds
# 第5次找到最佳阈值：1,10,50,127,此时类间方差为1886.0134770951465
# Running time: 0.8512064999999893 Seconds
# 第6次找到最佳阈值：1,10,52,114,此时类间方差为1891.4517396814972
# Running time: 0.8544289999999819 Seconds
# 第7次找到最佳阈值：1,10,52,120,此时类间方差为1894.7248909265084
# Running time: 0.8551298999999801 Seconds
# 第8次找到最佳阈值：1,10,52,127,此时类间方差为1899.4357961512944
# Running time: 0.8562178999999901 Seconds
# 第9次找到最佳阈值：1,10,56,127,此时类间方差为1923.789105175331
# Running time: 0.8636441999999818 Seconds
# 第10次找到最佳阈值：1,10,58,127,此时类间方差为1927.0101237949787
# Running time: 0.8679680999999846 Seconds
# 第11次找到最佳阈值：1,10,61,127,此时类间方差为1937.3775168572856
# Running time: 0.8736978000000022 Seconds
# 第12次找到最佳阈值：1,10,63,120,此时类间方差为1940.5570552765282
# Running time: 0.8772082999999782 Seconds
# 第13次找到最佳阈值：1,10,63,127,此时类间方差为1946.0605065924556
# Running time: 0.8779418999999962 Seconds
# 第14次找到最佳阈值：1,11,63,127,此时类间方差为1950.0137504159966
# Running time: 0.9830192999999952 Seconds
# 第15次找到最佳阈值：1,12,59,114,此时类间方差为1957.9205561110302
# Running time: 1.082361800000001 Seconds
# 第16次找到最佳阈值：1,12,59,120,此时类间方差为1961.736116123363
# Running time: 1.08301179999998 Seconds
# 第17次找到最佳阈值：1,12,59,127,此时类间方差为1967.0463155147636
# Running time: 1.083596799999981 Seconds
# 第18次找到最佳阈值：1,12,72,127,此时类间方差为1967.8303851998414
# Running time: 1.1074180999999896 Seconds
# 第19次找到最佳阈值：1,13,54,127,此时类间方差为1972.6896051705476
# Running time: 1.1806596999999783 Seconds
# 第20次找到最佳阈值：1,13,59,127,此时类间方差为1976.741708390337
# Running time: 1.1901859999999829 Seconds
# 第21次找到最佳阈值：1,13,64,114,此时类间方差为1988.7591142311503
# Running time: 1.1989269999999976 Seconds
# 第22次找到最佳阈值：1,13,64,120,此时类间方差为1992.8803067219728
# Running time: 1.1995772999999872 Seconds
# 第23次找到最佳阈值：1,13,64,127,此时类间方差为1998.5333062777909
# Running time: 1.2002991999999892 Seconds
# 第24次找到最佳阈值：1,14,55,114,此时类间方差为1998.573280717389
# Running time: 1.2897035000000017 Seconds
# 第25次找到最佳阈值：1,14,55,120,此时类间方差为2002.2684665096854
# Running time: 1.29038079999998 Seconds
# 第26次找到最佳阈值：1,14,55,127,此时类间方差为2007.4440261086886
# Running time: 1.291048499999988 Seconds
# 第27次找到最佳阈值：1,14,60,120,此时类间方差为2010.0060299343304
# Running time: 1.3011951999999951 Seconds
# 第28次找到最佳阈值：1,14,60,127,此时类间方差为2015.4715112549115
# Running time: 1.301649999999995 Seconds
# 第29次找到最佳阈值：1,14,69,114,此时类间方差为2025.1452082210003
# Running time: 1.3179329999999823 Seconds
# 第30次找到最佳阈值：1,14,69,120,此时类间方差为2029.5600416160041
# Running time: 1.3183265999999776 Seconds
# 第31次找到最佳阈值：1,14,69,127,此时类间方差为2035.546791046957
# Running time: 1.3189095999999836 Seconds
# 第32次找到最佳阈值：1,15,65,114,此时类间方差为2040.156138826665
# Running time: 1.416324799999984 Seconds
# 第33次找到最佳阈值：1,15,65,120,此时类间方差为2044.4175907770764
# Running time: 1.4169849999999826 Seconds
# 第34次找到最佳阈值：1,15,65,127,此时类间方差为2050.228982728301
# Running time: 1.417825999999991 Seconds
# 第35次找到最佳阈值：1,15,74,120,此时类间方差为2055.63739950683
# Running time: 1.4337257999999906 Seconds
# 第36次找到最佳阈值：1,15,74,127,此时类间方差为2061.871271449548
# Running time: 1.4344289999999944 Seconds
# 第37次找到最佳阈值：1,16,74,120,此时类间方差为2065.2378378372837
# Running time: 1.539809699999978 Seconds
# 第38次找到最佳阈值：1,16,74,127,此时类间方差为2071.4717097800017
# Running time: 1.5404843999999969 Seconds
# 第39次找到最佳阈值：1,16,79,127,此时类间方差为2072.3072234366045
# Running time: 1.550452999999976 Seconds
# 第40次找到最佳阈值：1,17,74,120,此时类间方差为2072.585686410143
# Running time: 1.6464474999999936 Seconds
# 第41次找到最佳阈值：1,17,74,127,此时类间方差为2078.819558352861
# Running time: 1.6471957999999916 Seconds
# 第42次找到最佳阈值：1,17,79,127,此时类间方差为2080.4602872630735
# Running time: 1.6573585999999807 Seconds
# 第43次找到最佳阈值：1,18,74,127,此时类间方差为2085.3020418028323
# Running time: 1.7540395999999987 Seconds
# 第44次找到最佳阈值：1,18,79,127,此时类间方差为2087.627789754077
# Running time: 1.7644863999999814 Seconds
# 第45次找到最佳阈值：1,19,74,127,此时类间方差为2090.3848562772537
# Running time: 1.8607405999999855 Seconds
# 第46次找到最佳阈值：1,19,79,127,此时类间方差为2093.231165951759
# Running time: 1.8702366999999924 Seconds
# 第47次找到最佳阈值：1,20,74,127,此时类间方差为2095.4261774457914
# Running time: 1.9675916999999856 Seconds
# 第48次找到最佳阈值：1,20,79,127,此时类间方差为2098.774489619142
# Running time: 1.977859599999988 Seconds
# 第49次找到最佳阈值：1,21,74,127,此时类间方差为2099.817042577768
# Running time: 2.0744724999999846 Seconds
# 第50次找到最佳阈值：1,21,79,127,此时类间方差为2103.591017718032
# Running time: 2.084009199999997 Seconds
# 第51次找到最佳阈值：1,22,74,127,此时类间方差为2103.8470105626197
# Running time: 2.1801274999999976 Seconds
# 第52次找到最佳阈值：1,22,79,127,此时类间方差为2108.0022153021514
# Running time: 2.190110699999991 Seconds
# 第53次找到最佳阈值：1,23,74,127,此时类间方差为2108.110504111702
# Running time: 2.285985399999987 Seconds
# 第54次找到最佳阈值：1,23,79,127,此时类间方差为2112.6592180848056
# Running time: 2.296102300000001 Seconds
# 第55次找到最佳阈值：1,24,79,127,此时类间方差为2116.627773183897
# Running time: 2.40193339999999 Seconds
# Processing:img-4
# 第1次找到最佳阈值：1,10,50,110,此时类间方差为1795.3681783210382
# Running time: 0.844990700000011 Seconds
# 第2次找到最佳阈值：1,10,50,111,此时类间方差为1801.2517099189977
# Running time: 0.8456759999999974 Seconds
# 第3次找到最佳阈值：1,10,50,113,此时类间方差为1819.9953607620603
# Running time: 0.845966500000003 Seconds
# 第4次找到最佳阈值：1,10,50,114,此时类间方差为1884.9717181188432
# Running time: 0.8461274000000003 Seconds
# 第5次找到最佳阈值：1,10,50,120,此时类间方差为1889.6637000708072
# Running time: 0.846851799999996 Seconds
# 第6次找到最佳阈值：1,10,52,114,此时类间方差为1898.00399778402
# Running time: 0.8513446000000044 Seconds
# 第7次找到最佳阈值：1,10,52,120,此时类间方差为1902.5713295634714
# Running time: 0.8520321000000024 Seconds
# 第8次找到最佳阈值：1,10,58,113,此时类间方差为1916.0707058167293
# Running time: 0.8625399999999956 Seconds
# 第9次找到最佳阈值：1,10,58,114,此时类间方差为1929.062792210065
# Running time: 0.8626402000000155 Seconds
# 第10次找到最佳阈值：1,10,58,120,此时类间方差为1934.0296247630165
# Running time: 0.8630744000000163 Seconds
# 第11次找到最佳阈值：1,10,65,120,此时类间方差为1937.2307865221721
# Running time: 0.8757567000000108 Seconds
# 第12次找到最佳阈值：1,10,67,120,此时类间方差为1940.830406123917
# Running time: 0.8801347000000135 Seconds
# 第13次找到最佳阈值：1,10,74,120,此时类间方差为1941.0290830568276
# Running time: 0.893306999999993 Seconds
# 第14次找到最佳阈值：1,11,63,114,此时类间方差为1950.0231164451764
# Running time: 0.9796393999999964 Seconds
# 第15次找到最佳阈值：1,11,63,120,此时类间方差为1955.2914716116807
# Running time: 0.9802601000000095 Seconds
# 第16次找到最佳阈值：1,12,63,120,此时类间方差为1960.277509632955
# Running time: 1.0870702999999935 Seconds
# 第17次找到最佳阈值：1,12,72,114,此时类间方差为1963.2894027470024
# Running time: 1.1035897000000148 Seconds
# 第18次找到最佳阈值：1,12,72,120,此时类间方差为1968.959613082862
# Running time: 1.1042142000000013 Seconds
# 第19次找到最佳阈值：1,13,54,114,此时类间方差为1970.713509222617
# Running time: 1.1785969000000023 Seconds
# 第20次找到最佳阈值：1,13,54,120,此时类间方差为1975.5613071669584
# Running time: 1.1792749999999899 Seconds
# 第21次找到最佳阈值：1,13,59,114,此时类间方差为1976.7820360684582
# Running time: 1.1885297999999977 Seconds
# 第22次找到最佳阈值：1,13,59,120,此时类间方差为1981.8860950558271
# Running time: 1.189180499999992 Seconds
# 第23次找到最佳阈值：1,13,64,113,此时类间方差为1987.7162461934129
# Running time: 1.1985426999999902 Seconds
# 第24次找到最佳阈值：1,13,64,114,此时类间方差为2000.1548388327953
# Running time: 1.1990725999999938 Seconds
# 第25次找到最佳阈值：1,13,64,120,此时类间方差为2005.5600940338452
# Running time: 1.1996923000000095 Seconds
# 第26次找到最佳阈值：1,14,55,120,此时类间方差为2010.0400810177741
# Running time: 1.2913790000000063 Seconds
# 第27次找到最佳阈值：1,14,60,114,此时类间方差为2016.7945948402419
# Running time: 1.300379200000009 Seconds
# 第28次找到最佳阈值：1,14,60,120,此时类间方差为2022.0345839247695
# Running time: 1.3010328000000015 Seconds
# 第29次找到最佳阈值：1,14,73,120,此时类间方差为2027.6602802749373
# Running time: 1.3326317000000074 Seconds
# 第30次找到最佳阈值：1,15,60,120,此时类间方差为2029.7491338013954
# Running time: 1.4264046000000121 Seconds
# 第31次找到最佳阈值：1,15,65,114,此时类间方差为2051.264899720449
# Running time: 1.435776500000003 Seconds
# 第32次找到最佳阈值：1,15,65,120,此时类间方差为2056.7977683438357
# Running time: 1.4361629999999934 Seconds
# 第33次找到最佳阈值：1,16,65,114,此时类间方差为2058.2203709223813
# Running time: 1.5403584000000023 Seconds
# 第34次找到最佳阈值：1,16,65,120,此时类间方差为2063.7532395457674
# Running time: 1.5410155000000145 Seconds
# 第35次找到最佳阈值：1,16,74,114,此时类间方差为2068.4798025117393
# Running time: 1.5567048999999997 Seconds
# 第36次找到最佳阈值：1,16,74,120,此时类间方差为2074.3485022687946
# Running time: 1.5572793999999988 Seconds
# 第37次找到最佳阈值：1,17,74,114,此时类间方差为2075.7512611184975
# Running time: 1.6593429000000128 Seconds
# 第38次找到最佳阈值：1,17,74,120,此时类间方差为2081.6199608755524
# Running time: 1.659965800000009 Seconds
# 第39次找到最佳阈值：1,18,74,114,此时类间方差为2082.3960815949704
# Running time: 1.7645867999999894 Seconds
# 第40次找到最佳阈值：1,18,74,120,此时类间方差为2088.2647813520252
# Running time: 1.7652061999999944 Seconds
# 第41次找到最佳阈值：1,19,74,120,此时类间方差为2093.1806411411735
# Running time: 1.8673929999999928 Seconds
# 第42次找到最佳阈值：1,20,74,120,此时类间方差为2098.1702876291274
# Running time: 1.9730223999999907 Seconds
# 第43次找到最佳阈值：1,21,74,120,此时类间方差为2102.8107193766427
# Running time: 2.0795990000000018 Seconds
# 第44次找到最佳阈值：1,22,74,120,此时类间方差为2106.6109713034557
# Running time: 2.1810857000000112 Seconds
# 第45次找到最佳阈值：1,23,74,120,此时类间方差为2110.853912492792
# Running time: 2.2831573999999932 Seconds
# 第46次找到最佳阈值：1,24,74,120,此时类间方差为2114.8884207866686
# Running time: 2.3875606999999945 Seconds

# %%
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点
th1 = 5
th2 = 25
th3 = 80
th4 = 115
img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点  49, 109, 133, 240,
th1 = 49
th2 = 109
th3 = 133
th4 = 240
img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()
