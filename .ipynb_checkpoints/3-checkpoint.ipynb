# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %%
img = []
file = []
for i in range(1,6):
    f = '1-' + str(i) + '.png'
    file.append(f)
    temp = cv.imread(f,0)
    img.append(temp)

plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img[i],'gray')
    
plt.show()

# %%
print(np.array(img).shape)
print(type(img[0]))
h , w= img[0].shape
print(h,w)
# Out:
# (5, 350, 300)
# <class 'numpy.ndarray'>
# 350 300

# %%
plt.figure(figsize=(10,25))
for i in range(0,5): 
    plt.subplot(5,1,i+1)
    plt.title(file[i])
    plt.hist(img[i].ravel(),256)
plt.show()

# %%
plt.title(file[i])
plt.hist(img[i].ravel(),256)
plt.show()

# %%
color1 = [0,0,0]
color2 = [0,255,255]
color3 = [255,0,0]
color4 = [0,100,0]
color5 = [0,0,255]

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点
th1 = 5
th2 = 35
th3 = 90
th4 = 120
for i in range(0,5):
    img[i] = cv.GaussianBlur(img[i], (9,9),0)

img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
import cv2 as cv
import numpy as np
np.seterr(invalid='ignore') #之所以加这一句是因为下面除法的时候会除零报错
import matplotlib.pyplot as plt
import time
start = time.perf_counter()


def ostu5layers(img,i):  # 显示每一个灰度级的像素数概率
    print('Processing:img-'+str(i))
    high, wide = (h,w)
    pixels = cv.calcHist([img], [0], None, [256], [0, 256])  # 计算每个灰度级中所含像素数，返回的是一个（256,1）的数组
    p = pixels / (high * wide)  # 获得每个灰度级中像素数占总像素数比例则我们获得了p_i的一个向量
    x=np.linspace(1,256,256) #灰度级我们定义为从0到255好像不合适这样做平均灰度级时会忽略第一个数据，所以我们定义为从1到256
    x=x.reshape(256,1)  # 这一步是因为我们需要的不是秩为1的向量，可以不加这一句输出看看shape的区别，但这样我们得到了（256,1）的灰度级向量

    maxvar=0
    th1=0
    th2=0
    th3=0
    th4=0
    cnt=0
    for k1 in range(1,10):
        for k2 in range(k1+1,50):
            for k3 in range(50,110):
                for k4 in range(110,140):
                    w0 = np.sum(p[0:k1])
                    w1 = np.sum(p[k1:k2])
                    w2 = np.sum(p[k2:k3])
                    w3 = np.sum(p[k3:k4])
                    w4 = np.sum(p[k4:256])  # 注意python是左闭右开np.sum(p[0:256])=1
                    
                    u0 = np.dot(x[0:k1].T, p[0:k1])
                    u1 = np.dot(x[k1:k2].T, p[k1:k2])
                    u2 = np.dot(x[k2:k3].T, p[k2:k3])
                    u3 = np.dot(x[k3:k4].T, p[k3:k4])
                    u4 = np.dot(x[k4:256].T, p[k4:256])
                    
                    W = np.array([[w0, w1, w2, w3, w4]]).T  # 注意是两层中括号，用np.array组成的向量可以转置,输出矩阵大小等等操作
                    U = np.array([[int(u0), int(u1), int(u2), int(u3), int(u4)]]).T
                    UT = np.sum(U)
                    temp = (U - UT * W) * (U - UT * W) / W
                    varbetween = np.sum(temp)
                    if varbetween>maxvar:
                        cnt=cnt+1
                        maxvar=varbetween
                        th1=k1
                        th2=k2
                        th3=k3
                        th4=k4
                        print("第"+str(cnt)+"次找到最佳阈值："+str(th1)+","+str(th2)+","+str(th3)+","+str(th4)+","+"此时类间方差为"+str(maxvar))
                        end = time.perf_counter()
                        print('Running time: %s Seconds' % (end - start))
    # mean1 = int(np.dot(x[0:th1].T, p[0:th1]))
    # mean2 = int(np.dot(x[th1:th2].T, p[th1:th2]))
    # mean3 = int(np.dot(x[th2:256].T, p[th2:256]))
    
    img11 = np.zeros((350, 300,3),dtype=np.uint8)
    for row in range(0,h):
        for col in range(0,w):
            if img[row][col]<=th1:
                img11[row, col]=color1
            elif img[row][col]>th1 and img[row][col]<=th2:
                img11[row, col] =color2
            elif img[row][col]>th2 and img[row][col]<=th3:
                img11[row, col] = color3
            elif img[row][col]>th3 and img[row][col]<=th4:
                img11[row, col] = color4
            elif img[row][col]>th4:
                img11[row, col] = color5
    return img11

if __name__ == '__main__':
    img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
    for i in range(0,5):
        start = time.perf_counter()
        img1[i]=ostu5layers(img[i],i)
    plt.figure(figsize=(25,20))
    for i in range(0,5): 
        plt.subplot(1,5,i+1)
        plt.axis('off')
        plt.title(file[i])
        plt.imshow(img1[i])
    plt.show()
# Out:
# Processing:img-0
# 第1次找到最佳阈值：1,2,50,110,此时类间方差为1650.0518509396343
# Running time: 0.0008224999999999483 Seconds
# 第2次找到最佳阈值：1,2,50,114,此时类间方差为1700.1014799515867
# Running time: 0.0020367000000014457 Seconds
# 第3次找到最佳阈值：1,2,50,115,此时类间方差为1712.9325788099268
# Running time: 0.0022183000000008946 Seconds
# 第4次找到最佳阈值：1,2,52,110,此时类间方差为1720.5843578923834
# Running time: 0.006105200000000366 Seconds
# 第5次找到最佳阈值：1,2,52,114,此时类间方差为1724.0794610674418
# Running time: 0.006699100000000513 Seconds
# 第6次找到最佳阈值：1,2,52,115,此时类间方差为1736.9970842705852
# Running time: 0.007138600000001105 Seconds
# 第7次找到最佳阈值：1,2,53,110,此时类间方差为1758.4917996024492
# Running time: 0.00931500000000085 Seconds
# 第8次找到最佳阈值：1,2,53,114,此时类间方差为1762.1159576505754
# Running time: 0.009805700000001139 Seconds
# 第9次找到最佳阈值：1,2,53,115,此时类间方差为1774.8442898108478
# Running time: 0.010271300000001204 Seconds
# 第10次找到最佳阈值：1,2,65,110,此时类间方差为1780.4366169509233
# Running time: 0.03396690000000113 Seconds
# 第11次找到最佳阈值：1,2,65,114,此时类间方差为1784.5602859141527
# Running time: 0.03477860000000099 Seconds
# 第12次找到最佳阈值：1,2,65,115,此时类间方差为1796.3796247757714
# Running time: 0.03489090000000061 Seconds
# 第13次找到最佳阈值：1,3,65,115,此时类间方差为1797.9028761194968
# Running time: 0.16121180000000024 Seconds
# 第14次找到最佳阈值：1,4,65,115,此时类间方差为1799.5665780739605
# Running time: 0.2872798000000003 Seconds
# 第15次找到最佳阈值：1,5,65,115,此时类间方差为1799.9708738545469
# Running time: 0.44938520000000004 Seconds
# 第16次找到最佳阈值：1,6,65,115,此时类间方差为1800.558937353525
# Running time: 0.6214483000000008 Seconds
# 第17次找到最佳阈值：1,7,65,115,此时类间方差为1801.6045076029363
# Running time: 0.7824622000000012 Seconds
# 第18次找到最佳阈值：1,8,65,115,此时类间方差为1803.0009643364156
# Running time: 0.9472822000000001 Seconds
# 第19次找到最佳阈值：1,9,65,115,此时类间方差为1803.5517037550794
# Running time: 1.1312139000000005 Seconds
# 第20次找到最佳阈值：1,10,65,115,此时类间方差为1804.1498558484068
# Running time: 1.2727138 Seconds
# 第21次找到最佳阈值：1,10,69,115,此时类间方差为1811.12621479365
# Running time: 1.2823980000000006 Seconds
# 第22次找到最佳阈值：1,11,69,115,此时类间方差为1816.9273557778265
# Running time: 1.436368400000001 Seconds
# 第23次找到最佳阈值：1,12,58,115,此时类间方差为1820.6282523994132
# Running time: 1.5534703000000007 Seconds
# 第24次找到最佳阈值：1,12,62,115,此时类间方差为1828.9658545382495
# Running time: 1.5638934000000013 Seconds
# 第25次找到最佳阈值：1,13,62,115,此时类间方差为1836.944992311539
# Running time: 1.7155627000000013 Seconds
# 第26次找到最佳阈值：1,13,76,110,此时类间方差为1838.1507917795077
# Running time: 1.7470797000000005 Seconds
# 第27次找到最佳阈值：1,13,76,114,此时类间方差为1842.5709667380206
# Running time: 1.7476436 Seconds
# 第28次找到最佳阈值：1,13,76,115,此时类间方差为1853.5448896624366
# Running time: 1.7484651000000007 Seconds
# 第29次找到最佳阈值：1,14,66,114,此时类间方差为1856.645657741375
# Running time: 1.8664722000000005 Seconds
# 第30次找到最佳阈值：1,14,66,115,此时类间方差为1868.2573008649956
# Running time: 1.8665834000000014 Seconds
# 第31次找到最佳阈值：1,14,73,115,此时类间方差为1874.300587323934
# Running time: 1.8810090000000006 Seconds
# 第32次找到最佳阈值：1,15,66,115,此时类间方差为1874.5383563301334
# Running time: 2.003462800000001 Seconds
# 第33次找到最佳阈值：1,15,70,115,此时类间方差为1886.1533180186116
# Running time: 2.012864800000001 Seconds
# 第34次找到最佳阈值：1,16,63,115,此时类间方差为1893.5098229805385
# Running time: 2.176315800000001 Seconds
# 第35次找到最佳阈值：1,16,70,115,此时类间方差为1895.0930517324714
# Running time: 2.2008378000000004 Seconds
# 第36次找到最佳阈值：1,17,63,115,此时类间方差为1898.554370964685
# Running time: 2.3790038000000013 Seconds
# 第37次找到最佳阈值：1,17,70,115,此时类间方差为1901.7766970666826
# Running time: 2.4022031000000013 Seconds
# 第38次找到最佳阈值：1,17,80,115,此时类间方差为1913.3404290320536
# Running time: 2.431972 Seconds
# 第39次找到最佳阈值：1,18,80,115,此时类间方差为1920.5548824199873
# Running time: 2.5781372000000005 Seconds
# 第40次找到最佳阈值：1,19,80,115,此时类间方差为1926.4551494126763
# Running time: 2.7144416000000007 Seconds
# 第41次找到最佳阈值：1,20,80,115,此时类间方差为1932.4454648870483
# Running time: 2.8593057 Seconds
# 第42次找到最佳阈值：1,21,80,115,此时类间方差为1937.987125336294
# Running time: 2.9869559 Seconds
# 第43次找到最佳阈值：1,22,80,115,此时类间方差为1943.4133975288382
# Running time: 3.1161612000000005 Seconds
# 第44次找到最佳阈值：1,23,80,115,此时类间方差为1948.6864659844314
# Running time: 3.250841600000001 Seconds
# 第45次找到最佳阈值：1,24,80,115,此时类间方差为1953.9846486714705
# Running time: 3.3842961000000003 Seconds
# 第46次找到最佳阈值：1,25,80,115,此时类间方差为1959.2227219782985
# Running time: 3.506592300000001 Seconds
# 第47次找到最佳阈值：1,26,80,115,此时类间方差为1964.7062918825231
# Running time: 3.6235379000000023 Seconds
# 第48次找到最佳阈值：1,27,80,115,此时类间方差为1969.347182647185
# Running time: 3.7432240000000014 Seconds
# 第49次找到最佳阈值：8,28,80,115,此时类间方差为1974.7738378976283
# Running time: 45.2668838 Seconds
# Processing:img-1
# 第1次找到最佳阈值：1,2,50,110,此时类间方差为1638.1335647409592
# Running time: 0.000633499999992182 Seconds
# 第2次找到最佳阈值：1,2,50,111,此时类间方差为1648.6813667329259
# Running time: 0.0008575999999891337 Seconds
# 第3次找到最佳阈值：1,2,50,112,此时类间方差为1658.4499569613824
# Running time: 0.0011303999999938696 Seconds
# 第4次找到最佳阈值：1,2,50,113,此时类间方差为1717.4199512985826
# Running time: 0.0014652999999924532 Seconds
# 第5次找到最佳阈值：1,2,50,114,此时类间方差为1729.4430806533253
# Running time: 0.0016841999999996915 Seconds
# 第6次找到最佳阈值：1,2,51,114,此时类间方差为1766.8984118463716
# Running time: 0.004947899999990568 Seconds
# 第7次找到最佳阈值：1,2,55,114,此时类间方差为1767.03548943588
# Running time: 0.013187000000002058 Seconds
# 第8次找到最佳阈值：1,2,56,114,此时类间方差为1801.7188390375866
# Running time: 0.01597649999999362 Seconds
# 第9次找到最佳阈值：1,2,67,114,此时类间方差为1809.7660152998735
# Running time: 0.04922769999998877 Seconds
# 第10次找到最佳阈值：1,2,71,114,此时类间方差为1823.4701485491526
# Running time: 0.06222989999999129 Seconds
# 第11次找到最佳阈值：1,3,71,114,此时类间方差为1824.816108196297
# Running time: 0.192798499999995 Seconds
# 第12次找到最佳阈值：1,4,71,114,此时类间方差为1827.701573584514
# Running time: 0.3301395999999954 Seconds
# 第13次找到最佳阈值：1,5,71,114,此时类间方差为1828.2477353684137
# Running time: 0.4612289999999888 Seconds
# 第14次找到最佳阈值：1,6,71,114,此时类间方差为1828.954839145814
# Running time: 0.5867756999999898 Seconds
# 第15次找到最佳阈值：1,7,71,114,此时类间方差为1829.5199378576142
# Running time: 0.7203946999999999 Seconds
# 第16次找到最佳阈值：1,8,71,114,此时类间方差为1832.2434532005284
# Running time: 0.8677558999999917 Seconds
# 第17次找到最佳阈值：1,9,71,114,此时类间方差为1832.8650272098555
# Running time: 1.0028590000000008 Seconds
# 第18次找到最佳阈值：1,10,71,114,此时类间方差为1833.6380014810668
# Running time: 1.155375399999997 Seconds
# 第19次找到最佳阈值：1,11,71,114,此时类间方差为1836.9506028533012
# Running time: 1.2760212999999965 Seconds
# 第20次找到最佳阈值：1,12,71,114,此时类间方差为1844.3766601782456
# Running time: 1.4151871999999912 Seconds
# 第21次找到最佳阈值：1,13,62,114,此时类间方差为1848.9770493671133
# Running time: 1.5232054999999889 Seconds
# 第22次找到最佳阈值：1,13,71,114,此时类间方差为1860.05136961604
# Running time: 1.541433799999993 Seconds
# 第23次找到最佳阈值：1,14,71,114,此时类间方差为1872.1863028286277
# Running time: 1.6737614999999977 Seconds
# 第24次找到最佳阈值：1,15,66,113,此时类间方差为1881.4009720171236
# Running time: 1.792743299999998 Seconds
# 第25次找到最佳阈值：1,15,66,114,此时类间方差为1892.1982935677486
# Running time: 1.7928627000000006 Seconds
# 第26次找到最佳阈值：1,16,66,114,此时类间方差为1900.2925374794188
# Running time: 1.9179290000000009 Seconds
# 第27次找到最佳阈值：1,16,70,113,此时类间方差为1902.3492436986928
# Running time: 1.9270966999999928 Seconds
# 第28次找到最佳阈值：1,16,70,114,此时类间方差为1912.8505950524761
# Running time: 1.9272132999999911 Seconds
# 第29次找到最佳阈值：1,17,70,114,此时类间方差为1919.470947981669
# Running time: 2.0682789999999898 Seconds
# 第30次找到最佳阈值：1,18,63,114,此时类间方差为1922.4406200016906
# Running time: 2.191804199999993 Seconds
# 第31次找到最佳阈值：1,18,70,114,此时类间方差为1924.350477109444
# Running time: 2.2074381999999986 Seconds
# 第32次找到最佳阈值：1,18,77,113,此时类间方差为1926.70761764348
# Running time: 2.2224779000000012 Seconds
# 第33次找到最佳阈值：1,18,77,114,此时类间方差为1936.7110039827749
# Running time: 2.2229672999999934 Seconds
# 第34次找到最佳阈值：1,19,77,114,此时类间方差为1942.019905704824
# Running time: 2.3581445999999886 Seconds
# 第35次找到最佳阈值：1,20,67,114,此时类间方差为1950.0052051684095
# Running time: 2.4742588999999953 Seconds
# 第36次找到最佳阈值：1,21,67,114,此时类间方差为1953.5937286640226
# Running time: 2.607214799999994 Seconds
# 第37次找到最佳阈值：1,21,74,114,此时类间方差为1967.6462343686587
# Running time: 2.621499700000001 Seconds
# 第38次找到最佳阈值：1,22,71,114,此时类间方差为1975.896503251503
# Running time: 2.7402912000000015 Seconds
# 第39次找到最佳阈值：1,23,71,114,此时类间方差为1979.858718837182
# Running time: 2.8772578999999894 Seconds
# 第40次找到最佳阈值：1,24,71,114,此时类间方差为1983.5757478148366
# Running time: 3.0144778999999886 Seconds
# 第41次找到最佳阈值：1,25,71,114,此时类间方差为1987.3178279796496
# Running time: 3.147487599999991 Seconds
# 第42次找到最佳阈值：1,26,71,114,此时类间方差为1990.61616497738
# Running time: 3.2948160999999914 Seconds
# 第43次找到最佳阈值：1,27,71,114,此时类间方差为1994.090001955211
# Running time: 3.4254377999999974 Seconds

# %%
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点
th1 = 5
th2 = 25
th3 = 80
th4 = 115
img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()

# %%
color1 = [0,0,0]     #黑色无用区域
color2 = [0,0,255]  #蓝色 海水
color3 = [95,158,160]   #红色 薄冰
color4 = [102,205,170]   # 厚冰
color5 = [255,0,0]  #红色 陆地
#手工设置阈值点  49, 109, 133, 240,
th1 = 49
th2 = 109
th3 = 133
th4 = 240
img1 = np.zeros((5, 350, 300,3),dtype=np.uint8)
for i in range(0,5):
    for row in range(0,h):
        for col in range(0,w):
            if img[i][row][col]<=th1:
                img1[i,row, col]=color1
            elif img[i][row][col]>th1 and img[i][row][col]<=th2:
                img1[i,row, col] =color2
            elif img[i][row][col]>th2 and img[i][row][col]<=th3:
                img1[i,row, col] = color3
            elif img[i][row][col]>th3 and img[i][row][col]<=th4:
                img1[i,row, col] = color4
            elif img[i][row][col]>th4:
                img1[i,row, col] = color5
plt.figure(figsize=(25,20))
for i in range(0,5): 
    plt.subplot(1,5,i+1)
    plt.axis('off')
    plt.title(file[i])
    plt.imshow(img1[i])
plt.show()
